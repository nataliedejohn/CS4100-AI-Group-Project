# %%
import pandas as pd
from pathlib import Path

# %%
data_path = Path("cleaned_output/player_week_features_clean.csv")

df = pd.read_csv(data_path, parse_dates=['week_start', 'week_end'])
df
# Out:
#       player_id   week_id week_start   week_end  season  label_hr  reward  \
# 0        457759  2023-W14 2023-04-03 2023-04-09    2023         0       0
# 1        457759  2023-W15 2023-04-10 2023-04-16    2023         1       1
# 2        457759  2023-W16 2023-04-17 2023-04-23    2023         1       1
# 3        457759  2023-W17 2023-04-24 2023-04-30    2023         0       0
# 4        457759  2023-W18 2023-05-01 2023-05-07    2023         0       0
# ...         ...       ...        ...        ...     ...       ...     ...
# 3652     807799  2023-W35 2023-08-28 2023-09-03    2023         1       1
# 3653     807799  2023-W36 2023-09-04 2023-09-10    2023         1       1
# 3654     807799  2023-W37 2023-09-11 2023-09-17    2023         0       0
# 3655     807799  2023-W38 2023-09-18 2023-09-24    2023         0       0
# 3656     807799  2023-W39 2023-09-25 2023-10-01    2023         0       0
#
#       prev_games_played  prev_pa_roll_7  prev_pa_roll_14  prev_pa_roll_28  \
# ...

# %%
df.describe().T
# Out:
#                       count                           mean  \
# player_id            3657.0                  633704.051135
# week_start             3657  2023-06-30 09:12:03.543888384
# week_end               3657  2023-07-06 09:12:03.543888384
# season               3657.0                         2023.0
# label_hr             3657.0                       0.818977
# reward               3657.0                        0.73038
# prev_games_played    3657.0                        5.45283
# prev_pa_roll_7       3657.0                      21.811321
# prev_pa_roll_14      3657.0                      43.622642
# prev_pa_roll_28      3657.0                      87.245283
# prev_pa_per_game     3657.0                            4.0
# prev_hr_rate_7       3657.0                       0.009361
# prev_hr_rate_14      3657.0                       0.009379
# prev_hr_rate_28      3657.0                       0.009379
# prev_hr_rate_season  3657.0                       0.009154
# ...

# %%
df_season = pd.read_csv("player_season_meta.csv")
df_season
# Out:
#      player_id               Name   PA  season
# 0        18401   Ronald Acuna Jr.  735    2023
# 1         5361    Freddie Freeman  730    2023
# 2        13611       Mookie Betts  693    2023
# 3        19755      Shohei Ohtani  599    2023
# 4        14344         Matt Olson  720    2023
# ..         ...                ...  ...     ...
# 129      19610       Keibert Ruiz  562    2023
# 130      15676         Jose Abreu  594    2023
# 131      17988   Tyler Stephenson  517    2023
# 132      10472  Enrique Hernandez  508    2023
# 133      10815   Jurickson Profar  521    2023
#
# [134 rows x 4 columns]
